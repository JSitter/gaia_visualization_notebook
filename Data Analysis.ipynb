# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from astroML.plotting import plot_tissot_ellipse
import healpy as hp
import json
# %matplotlib inline
plt.figure(figsize=(20,10))

# %%
def read_data(filename):
    return pd.read_csv("./Datasets/" + str(filename))

def hist(filename):
    df = read_data(filename)
#     display(df.hist(figsize=(15,25)))

# %%
json_str = read_json("random_index-700k.json")
df = pd.read_json(json_str)
df.head()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-21-2b6e8a545015> in <module>()
# ----> 1 json_str = read_json("random_index-700k.json")
#       2 df = pd.read_json(json_str)
#       3 df.head()
#
# <ipython-input-20-75c196fa13aa> in read_json(filename)
#       4 def read_json(filename):
#       5     with open('./Datasets/'+filename) as f:
# ----> 6         data = json.load(f)
#       7     return data
#       8
#
# /anaconda3/lib/python3.6/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     297         cls=cls, object_hook=object_hook,
#     298         parse_float=parse_float, parse_int=parse_int,
# --> 299         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     300
#     301
#
# ...

# %%
setup_text_plots(fontsize=8, usetex=False)

# %%
df = read_data("GaiaSource_2851858288640_1584379458008952960.csv")

# %%
df.head()
# Out:
#            solution_id              designation       source_id  random_index  \
# 0  1635721458409799680   Gaia DR2 2851858288640   2851858288640     710827874
# 1  1635721458409799680   Gaia DR2 3332894779520   3332894779520    1512134789
# 2  1635721458409799680   Gaia DR2 7632157690368   7632157690368     830339102
# 3  1635721458409799680   Gaia DR2 9281425163264   9281425163264    1074475725
# 4  1635721458409799680  Gaia DR2 12545600306304  12545600306304     614396172
#
#    ref_epoch         ra  ra_error       dec  dec_error  parallax  \
# 0     2015.5  45.132144  0.051487  0.137851   0.039624  2.618833
# 1     2015.5  45.058167  0.037937  0.127404   0.038226  1.742291
# 2     2015.5  45.034337  0.053568  0.235391   0.037913  5.692796
# 3     2015.5  45.165008  0.045778  0.200060   0.040007  3.750882
# 4     2015.5  45.234476  0.034646  0.318159   0.033514  4.257022
#
#            ...           e_bp_min_rp_val  e_bp_min_rp_percentile_lower  \
# ...

# %%
# Hertzsprung–Russell diagram
# Scatter plot of luminositiy vs effective temperatures
abs_mag = list()

#d = 1/p

clean
plt.figure(figsize=(17, 25), dpi=300)
plt.scatter(x=df['teff_val'], y=df['radial_velocity'], s=1)
plt.show()
# Out:
#                 solution_id                   designation  \
# 94      1635721458409799680      Gaia DR2 305771607451904
# 5150    1635721458409799680    Gaia DR2 16374515572051712
# 5428    1635721458409799680    Gaia DR2 17451723433969408
# 6054    1635721458409799680    Gaia DR2 19526437451623552
# 7351    1635721458409799680    Gaia DR2 23781547451165824
# 7517    1635721458409799680    Gaia DR2 24254337451364992
# 8148    1635721458409799680    Gaia DR2 26074510231529600
# 8345    1635721458409799680    Gaia DR2 26647355789745152
# 8958    1635721458409799680    Gaia DR2 28567137451360768
# 9485    1635721458409799680    Gaia DR2 30003374515237632
# 9770    1635721458409799680    Gaia DR2 30745196970914176
# 10353   1635721458409799680    Gaia DR2 32187451284688000
# 10742   1635721458409799680    Gaia DR2 33227451845652864
# 11516   1635721458409799680    Gaia DR2 35158327407451136
# 13615   1635721458409799680    Gaia DR2 40277451685484672
# ...

# %%
mapp = hp.read_map('./Datasets/VariRotationModulation_0.fits')
map_rot=hp.mollview(mapp, coords=['G', 'C'])
# Out:
# /anaconda3/lib/python3.6/site-packages/healpy/fitsfunc.py:327: HealpixFitsWarning: No NSIDE in the header file : will use length of array
#   "No NSIDE in the header file : will use length of array", HealpixFitsWarning
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-fe1030bb7146> in <module>()
# ----> 1 mapp = hp.read_map('./Datasets/VariRotationModulation_0.fits')
#       2 map_rot=hp.mollview(mapp, coords=['G', 'C'])
#
# /anaconda3/lib/python3.6/site-packages/healpy/fitsfunc.py in read_map(filename, field, dtype, nest, partial, hdu, h, verbose, memmap)
#     330         nside = int(nside)
#     331     if verbose:
# --> 332         print("NSIDE = {0:d}".format(nside))
#     333
#     334     if not pixelfunc.isnsideok(nside):
#
# TypeError: unsupported format string passed to NoneType.__format__

# %%
# import matplotlib.pyplot as plt


# plt.subplot(111, projection="aitoff")
# plt.title("Aitoff")
# plt.grid(True)

# plt.figure(figsize=(20,10))
# plt.subplot(111, projection="hammer")
# plt.title("Hammer")
# plt.grid(True)

# plt.figure(figsize=(20,10))
# plt.subplot(111, projection="lambert")
# plt.title("Lambert")
# plt.grid(True)

# plt.figure(figsize=(20,10))
# plt.subplot(111, projection="mollweide")
# plt.title("Mollweide")
# plt.grid(True)

# plt.show()

# %%
def plot_mwd(RA,Dec,org=0,title='Mollweide projection', projection='mollweide', colors=None):
    ''' RA, Dec are arrays of the same length.
    RA takes values in [0,360), Dec in [-90,90],
    which represent angles in degrees.
    org is the origin of the plot, 0 or a multiple of 30 degrees in [0,360).
    title is the title of the figure.
    projection is the kind of projection: 'mollweide', 'aitoff', 'hammer', 'lambert'
    '''
    plt.style.use('dark_background')
    x = np.remainder(RA+360-org,360) # shift RA values
    ind = x>180
    x[ind] -=360    # scale conversion to [-180, 180]
    x=-x    # reverse the scale: East to the left
    tick_labels = np.array([150, 120, 90, 60, 30, 0, 330, 300, 270, 240, 210])
    tick_labels = np.remainder(tick_labels+360+org,360)
    fig = plt.figure(figsize=(30, 15))
    ax = fig.add_subplot(111, projection=projection)
    if colors:
        ax.scatter(np.radians(x),np.radians(Dec), s=1, c=colors)
    else:
        ax.scatter(np.radians(x),np.radians(Dec), s=1)  # convert degrees to radians
    ax.set_xticklabels(tick_labels)     # we add the scale on the x axis
    ax.set_title(title)

    ax.set_xlabel("RA")

    ax.set_ylabel("Dec")

    ax.grid(True)

# %%
df = read_data('brightest-result-bigger.csv')
display(df.head())
# Out:
#           ra        dec  phot_bp_mean_mag
# 0  72.693622 -73.546642         19.615814
# 1  73.369647 -73.357476         19.566374
# 2  72.299553 -73.411260         19.535177
# 3  73.536722 -73.481835         19.651432
# 4  72.270396 -73.505422         19.969753
# 3000000

# %%
df.sort_values(by=['phot_bp_mean_mag'], ascending=False)
coords = list()
colors = list()
#create list of colors
for index in range(len(df)):
    ra = df.iloc[index]['ra']
    dec = df.iloc[index]['dec']
    coords.append(( ra, dec ))
    magnitude = float(df.iloc[index]['phot_bp_mean_mag'])
    if magnitude < 4.0:
        colors.append((1.0, 1.0, 1.0))
    elif magnitude < 5.5:
        colors.append((.9, .9, .9))
    elif magnitude <  7.0:
        colors.append((.8, .8, .8))
    elif magnitude < 8.5:
        colors.append((.7, .7, .7))
    elif magnitude < 10:
        colors.append((.6, .6, .6))
    elif magnitude < 11.5:
        colors.append((.5, .5, .5))
    elif magnitude < 13:
        colors.append((.4, .4, .4))
    elif magnitude < 14.5:
        colors.append((.3, .3, .3))
    elif magnitude < 16:
        colors.append((.25, .25, .25))
    elif magnitude < 17.5:
        colors.append((.2, .2, .2))
    elif magnitude < 30:
        colors.append((.15, .15, .15))
    else:
        colors.append((.0, .0, .0))

display(len(coords))  
coord = np.array(coords)
plot_mwd(coord[:,0],coord[:,1], org=90, title ='The Sky as seen by Gaia Mollweide Projection', colors=colors)
# Out:
# 3000000

# %%
df.sort_values(by=['phot_bp_mean_mag'])
df.head()
coords = list()
colors = list()
#create list of colors
for index in range(len(df)):
    ra = df.iloc[index]['ra']
    dec = df.iloc[index]['dec']
    coords.append(( ra, dec ))
    magnitude = float(df.iloc[index]['phot_bp_mean_mag'])
    if magnitude < 4.0:
        colors.append((1.0, 1.0, 1.0))
    elif magnitude < 5.5:
        colors.append((.9, .9, .9))
    elif magnitude <  7.0:
        colors.append((.85, .85, .85))
    elif magnitude < 8.5:
        colors.append((.8, .8, .8))
    elif magnitude < 10:
        colors.append((.75, .75, .75))
    elif magnitude < 11.5:
        colors.append((.7, .7, .7))
    elif magnitude < 13:
        colors.append((.65, .65, .65))
    elif magnitude < 14.5:
        colors.append((.6, .6, .6))
    elif magnitude < 16:
        colors.append((.55, .55, .55))
    elif magnitude < 17.5:
        colors.append((.5, .5, .5))
    elif magnitude < 30:
        colors.append((.45, .45, .45))
    else:
        colors.append((.4, .4, .4))

display(len(coords))  
coord = np.array(coords)
plot_mwd(coord[:,0],coord[:,1], org=90, title ='The Sky as seen by Gaia Mollweide Projection', colors=colors)
# Out:
# 3000000

# %%
def plot_stars(RA,Dec,title='The Sky as seen by Gaia', projection='mollweide', colors=None):

    plt.style.use('dark_background')

    x = np.remainder(RA+360,360) # shift RA values
    ind = x>180
    x[ind] -=360    # scale conversion to [-180, 180]
    x=-x    # reverse the scale: East to the left


    fig = plt.figure(figsize=(30, 15))
    # Projection types: 'mollweide', 'aitoff', 'hammer', 'lambert'
    ax = fig.add_subplot(111, projection=projection)
    if colors:
        ax.scatter(np.radians(x),np.radians(Dec), s=1, c=colors)
    else:
        ax.scatter(np.radians(RA),np.radians(Dec), s=1)  # convert degrees to radians

# %%
df = read_data('brightest-result.csv')
df.head()
# Out:
#            ra        dec  phot_bp_mean_mag
# 0  241.359277 -19.805548          2.985573
# 1   59.463592  40.010099          3.036183
# 2  245.297087 -25.592879          3.057587
# 3   56.871247  24.104940          3.064981
# 4   10.127231  56.537194          3.136008

# %%
#create list of colors
colors = []
for index in range(len(df)):
    ra = df.iloc[index]['ra']
    dec = df.iloc[index]['dec']
    coords.append(( ra, dec ))
    magnitude = float(df.iloc[index]['phot_bp_mean_mag'])
    if magnitude < 4.0:
        colors.append((1.0, 1.0, 1.0))
    elif magnitude < 5.5:
        colors.append((.9, .9, .9))
    elif magnitude <  7.0:
        colors.append((.8, .8, .8))
    elif magnitude < 8.5:
        colors.append((.7, .7, .7))
    elif magnitude < 10:
        colors.append((.6, .6, .6))
    elif magnitude < 11.5:
        colors.append((.5, .5, .5))
    elif magnitude < 13:
        colors.append((.4, .4, .4))
    elif magnitude < 14.5:
        colors.append((.3, .3, .3))
    elif magnitude < 16:
        colors.append((.25, .25, .25))
    elif magnitude < 17.5:
        colors.append((.2, .2, .2))
    elif magnitude < 30:
        colors.append((.15, .15, .15))
    else:
        colors.append((.0, .0, .0))

display(len(coords))  
coord = np.array(coords)
# Out:
# 3038082

# %%
plot_stars(coord[:,0], coord[:,1], colors=colors)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/projections/geo.py:426: RuntimeWarning: invalid value encountered in arcsin
#   theta = np.arcsin(y / np.sqrt(2))
